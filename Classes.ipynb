# %% [markdown]
# <a href="https://colab.research.google.com/github/iamkishan98/Deep-learning-assignments/blob/master/Classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class C1():
  def __init__(self,fname,lname):
    self.fname = fname
    self.lname = lname
    self.fullname = self.fname +" "+  self.lname
    print(self.fullname)

obj = C1("Gopikishan","Thawre")
print(obj.fname)
print(obj.lname)
print(obj.fullname)
# Out:
# Gopikishan Thawre
# Gopikishan
# Thawre
# Gopikishan Thawre

# %%
# Displaying Images
from google.colab import drive
drive.mount('/content/drive')
import os 
os.chdir('/content/drive/My Drive/')
os.listdir('/content/drive/My Drive/')
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as matimage

a= matimage.imread('st.png')
plt.imshow(a)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
a = cv2.imread('st.png')
plt.imshow(a)
plt.imshow(a,'gray')
